# %% [markdown]
# <a href="https://colab.research.google.com/github/nguyenhau442001/Homework_AI/blob/main/MNIST_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import mnist
from sklearn import utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout,Conv2D,MaxPooling2D,Flatten
from tensorflow.keras.optimizers import RMSprop,Adam
import numpy as np
from keras.utils import np_utils
import pandas as pd
from keras.callbacks import EarlyStopping 
import matplotlib.pyplot as plt

# Load data
(x_train,y_train),(x_test,y_test)=mnist.load_data()

# Force to data type
x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

x_train=x_train.reshape(60000,28,28,1)
x_test=x_test.reshape(10000,28,28,1)
# Divide in 255 to ensure value always between 0 and 1
x_train/=255
x_test/=255

# Convert labels to one hot-encoding
y_train=np_utils.to_categorical(y_train,10)
y_test=np_utils.to_categorical(y_test,10)


# Create model 
model = Sequential()
model.add(Conv2D(64,(3,3),activation='relu',input_shape=(28,28,1)))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3),input_shape=(28,28),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(10, activation='softmax'))
model.summary()

# Compile
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Training
history=model.fit(x_train,y_train,batch_size=128,epochs=500,verbose=1,validation_data=(x_test,y_test),callbacks=[EarlyStopping(monitor='val_loss',patience=20)])
# Plot
plt.plot(history.history['accuracy'])
plt.xlabel('epoch')
plt.legend(['accuracy'])
plt.show()

# Evaluate
score = model.evaluate(x_test, y_test, verbose=0)
print('Test error:',score[0])
print('Test accuracy: ',score[1])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 128)               204928
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 243,786
# Trainable params: 243,786
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 469/469 [==============================] - 82s 172ms/step - loss: 0.1926 - accuracy: 0.9430 - val_loss: 0.0587 - val_accuracy: 0.9816
# Epoch 2/500
# 469/469 [==============================] - 79s 169ms/step - loss: 0.0537 - accuracy: 0.9836 - val_loss: 0.0385 - val_accuracy: 0.9881
# Epoch 3/500
# 469/469 [==============================] - 78s 166ms/step - loss: 0.0368 - accuracy: 0.9888 - val_loss: 0.0366 - val_accuracy: 0.9868
# Epoch 4/500
# 469/469 [==============================] - 78s 166ms/step - loss: 0.0279 - accuracy: 0.9912 - val_loss: 0.0312 - val_accuracy: 0.9906
# Epoch 5/500
# 469/469 [==============================] - 79s 168ms/step - loss: 0.0221 - accuracy: 0.9929 - val_loss: 0.0380 - val_accuracy: 0.9875
# Epoch 6/500
# 469/469 [==============================] - 75s 161ms/step - loss: 0.0168 - accuracy: 0.9945 - val_loss: 0.0274 - val_accuracy: 0.9909
# Epoch 7/500
# 469/469 [==============================] - 75s 160ms/step - loss: 0.0147 - accuracy: 0.9951 - val_loss: 0.0273 - val_accuracy: 0.9917
# Epoch 8/500
# 469/469 [==============================] - 75s 160ms/step - loss: 0.0117 - accuracy: 0.9959 - val_loss: 0.0279 - val_accuracy: 0.9912
# Epoch 9/500
# 469/469 [==============================] - 75s 160ms/step - loss: 0.0089 - accuracy: 0.9971 - val_loss: 0.0312 - val_accuracy: 0.9908
# Epoch 10/500
# 469/469 [==============================] - 75s 161ms/step - loss: 0.0077 - accuracy: 0.9973 - val_loss: 0.0357 - val_accuracy: 0.9896
# Epoch 11/500
# 469/469 [==============================] - 75s 160ms/step - loss: 0.0075 - accuracy: 0.9976 - val_loss: 0.0322 - val_accuracy: 0.9912
# Epoch 12/500
# 469/469 [==============================] - 75s 160ms/step - loss: 0.0060 - accuracy: 0.9977 - val_loss: 0.0374 - val_accuracy: 0.9908
# Epoch 13/500
# 469/469 [==============================] - 75s 159ms/step - loss: 0.0056 - accuracy: 0.9982 - val_loss: 0.0357 - val_accuracy: 0.9904
# Epoch 14/500
# 469/469 [==============================] - 75s 159ms/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.0410 - val_accuracy: 0.9899
# Epoch 15/500
# 469/469 [==============================] - 74s 159ms/step - loss: 0.0044 - accuracy: 0.9986 - val_loss: 0.0405 - val_accuracy: 0.9905
# Epoch 16/500
# 469/469 [==============================] - 74s 159ms/step - loss: 0.0039 - accuracy: 0.9987 - val_loss: 0.0381 - val_accuracy: 0.9913
# Epoch 17/500
# 469/469 [==============================] - 75s 159ms/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.0358 - val_accuracy: 0.9914
# Epoch 18/500
# 469/469 [==============================] - 74s 159ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.0425 - val_accuracy: 0.9904
# Epoch 19/500
# 469/469 [==============================] - 74s 159ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.0501 - val_accuracy: 0.9898
# Epoch 20/500
# 469/469 [==============================] - 75s 160ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.0381 - val_accuracy: 0.9917
# Epoch 21/500
# 469/469 [==============================] - 75s 160ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0403 - val_accuracy: 0.9903
# Epoch 22/500
# 469/469 [==============================] - 75s 160ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.0401 - val_accuracy: 0.9922
# Epoch 23/500
# 469/469 [==============================] - 75s 160ms/step - loss: 0.0047 - accuracy: 0.9984 - val_loss: 0.0679 - val_accuracy: 0.9862
# Epoch 24/500
# 469/469 [==============================] - 82s 174ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.0383 - val_accuracy: 0.9918
# Epoch 25/500
# 469/469 [==============================] - 82s 176ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0397 - val_accuracy: 0.9923
# Epoch 26/500
# 469/469 [==============================] - 83s 176ms/step - loss: 5.3533e-04 - accuracy: 0.9999 - val_loss: 0.0338 - val_accuracy: 0.9930
# Epoch 27/500
# 469/469 [==============================] - 83s 176ms/step - loss: 3.8722e-05 - accuracy: 1.0000 - val_loss: 0.0346 - val_accuracy: 0.9930
# Test error: 0.03462718054652214
# Test accuracy:  0.9929999709129333

# %%
# Predict
n=int(input("Index ? "))
print(x_test.shape)

y_predict = model.predict(x_test[n].reshape(1,28,28,1))
print('Predicted value: ', np.argmax(y_predict))
print('Correct value: ',np.argmax(y_test[n]))
# Out:
# Index ? 10
# (10000, 28, 28, 1)
# Predicted value:  0
# Correct value:  0

# %%
from keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np
(x_tr,y_tr),(x_t,y_t)=mnist.load_data()
for i in range(1,10):
  plt.subplot(330+i)
  plt.imshow(x_t[i],cmap='gray')
